# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt


n=cv2.imread('raw.jpg')
plt.figure(figsize=(12,15))
plt.imshow(n)
plt.show()

#raw results

# %%
n=cv2.imread('raw_lstm.jpg')
plt.figure(figsize=(12,15))
plt.imshow(n)
plt.show()
#lstm on raw

# %%
n=cv2.imread('tsne.jpg')
plt.figure(figsize=(12,15))
plt.imshow(n)
plt.show()

#lstm on preprocessed
